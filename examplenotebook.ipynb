# %% [markdown]
# # Example notebook to do interesting things
#
#
# what even

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = np.arange(1,32,1)
x = np.random.rand(31)

plt.plot(w,x)
plt.title('example')
# Out:
# Text(0.5, 1.0, 'example')
